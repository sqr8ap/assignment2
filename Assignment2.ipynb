# %% [markdown]
# <a href="https://colab.research.google.com/github/sqr8ap/assignment2/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Data Wrangling and Exploratory Data Analysis
# ## Do Q1 and Q2, and one other question.
# `! git clone https://www.github.com/DS3001/assignment2`

# %%
! git clone https://www.github.com/DS3001/assignment2
# Out:
# Cloning into 'assignment2'...
# ...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 36 (delta 8), reused 5 (delta 5), pack-reused 24
# Receiving objects: 100% (36/36), 5.47 MiB | 10.18 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %% [markdown]
# **Q1.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#   1. Read the abstract. What is this paper about?
#   2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#   3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#   4. Read Section 2.2. How does Wickham define values, variables, and observations?
#   5. How is "Tidy Data" defined in section 2.3?
#   6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#   7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#   8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?

# %% [markdown]
# 1. This paper is about data tidying, or restructuring datasets to allow for easy cleaning.
# 2. The "tidy data standard" is intended to offer a universal starting point for data exploration and analysis and to simplify the development of compatible analysis tools. Datasets come in many different formats, some of which can be very difficult to work with. The tidy structure allows for an easier and more straightforward cleaning process.
# 3. Sentence 1: Datasets in tidy format all have the same structure and are therefore very similar, but untidy datasets do not share structural characteristics and thus can differ in many more ways. Untidy datasets do not share some structural common denominator in the way that tidy datasets do, and that dissimilarity opens the door to countless potential differences. Sentence 2: When we are working with a dataset, it is generally easy to identify which elements are observations and which elements are variables, especially when we have the context of the data and understand what it is aiming to capture. However, defining a broadly applicable rule or convention for what is a variable and what is an observation is more difficult, as differences in structure present constraints that are not present when looking at one dataset in isolation.
# 4. The term 'value' describes the actual data points in a dataset. Values are generally either strings or numbers. Each value in a dataset maps to both a 'variable' and an 'observation.' Variables contain all values that measure the same underlying attribute across units, whereas observations contain all values measured on the same unit across attributes.
# 5. In a tidy dataset, the following is true: 1) each variable forms a column, 2) each observation forms a row, and 3) each type of observational unit forms a table. Tidy datasets can be categorized as third normal form.
# 6. The five most common problems with messy datasets are as follows: 1) column headers are values rather than variable names, 2) multiple variables are stored in one column, 3) variables are stored in both rows and columns, 4) multiple types of observational units are stored in the same table, and 5) a single observational unit is stored in multiple tables. Table 4 is considered messy because the column headers are values rather than variable names. Melting a dataset involves turning columns into rows and is often referred to as stacking. Melting a dataset eliminates the issue of having column headers that reflect values rather than variable names.
# 7. Table 11 is messy because there are columns for dates, but dates are values. Table 12a is molten because is has been elongated and includes a 'value' column that contains values initially found under the date columns (d1, d2, d3, etc). Table 12b is tidy because each row represents measurements for a single day, and the variables tmax and tmin have been made into columns.
# 8. If tidy data is only as useful as the tools that are compatible with it, then tidy tools will be inextricably linked to tidy data. Thus, workflow may not always be improved by tidying data. Wickham hopes that future work on the subject of data wrangling will yield better data storage strategies and tools; he hopes that future work will build upon the current tidy framework.

# %% [markdown]
# **Q2.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
# 2. Categorical variable: For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)

# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/content/assignment2/data/')
df = pd.read_csv('airbnb_hw.csv',low_memory=False)

# %%
# Cleaning the Price variable

var = 'Price'
df[var].str.replace(',','') # here I'm replacing the commas with empty strings
                            # to get rid of them before typecasting
df[var] = pd.to_numeric(df[var], errors='coerce') # here I'm coercing the Price values to numeric

print("After cleaning, there are ", sum(df[var].isnull()), " null values.")
# Out:
# After cleaning, there are  181  null values.

# %%
# Cleaning the Type variable

df = pd.read_csv('sharks.csv',low_memory=False)

var = 'Type'
# getting an idea of what the variable looks like:
print(df[var].unique())
print(df[var].value_counts())
print(sum(df[var].isnull()))

# replacing Boatomg, Boat, Boating with Watercraft
df[var] = df[var].replace(['Boatomg','Boat','Boating'],'Watercraft')
print(df[var].unique())

# replacing Unconfirmed, Unverified, Under investigation with Questionable
df[var] = df[var].replace(['Unconfirmed','Unverified','Under investigation'],'Questionable')
print(df[var].unique())

# my approach preserved the main categories that values can take on in this
    # column of the dataset; i did not convert anything to nan

# a different approach to cleaning this variable could include coding provoked
    # as 1 and unprovoked as 0 with nan for all other values:
df[var] = df[var].replace('Unprovoked',0)
df[var] = df[var].replace('Provoked',1)
df[var] = df[var].replace(['Questionable','Watercraft','Invalid','Sea Disaster'],np.nan)
print(df[var].value_counts())
print(sum(df[var].isnull()))
# Out:
# ['Unprovoked' 'Provoked' 'Questionable' 'Watercraft' 'Unconfirmed'
#  'Unverified' 'Invalid' 'Under investigation' 'Boating' 'Sea Disaster' nan
#  'Boat' 'Boatomg']
# Unprovoked             4716
# Provoked                593
# Invalid                 552
# Sea Disaster            239
# Watercraft              142
# Boat                    109
# Boating                  92
# Questionable             10
# Unconfirmed               1
# Unverified                1
# Under investigation       1
# Boatomg                   1
# Name: Type, dtype: int64
# 5
# ['Unprovoked' 'Provoked' 'Questionable' 'Watercraft' 'Unconfirmed'
#  'Unverified' 'Invalid' 'Under investigation' 'Sea Disaster' nan]
# ['Unprovoked' 'Provoked' 'Questionable' 'Watercraft' 'Invalid'
#  'Sea Disaster' nan]
# 0.0    4716
# 1.0     593
# Name: Type, dtype: int64
# 1153

# %%
# Cleaning the WhetherDefendantWasReleasedPretrial variable

url = 'http://www.vcsc.virginia.gov/pretrialdataproject/October%202017%20Cohort_Virginia%20Pretrial%20Data%20Project_Deidentified%20FINAL%20Update_10272021.csv'
df = pd.read_csv(url,low_memory=False)

# %%
df = df.rename(columns = {'WhetherDefendantWasReleasedPretrial':'Released'}) # renaming to something simpler
var = 'Released'
print(df[var].unique())
print(df[var].value_counts())
print(sum(df[var].isnull()))

# replacing 9s with nans:

df[var] = df[var].replace(9,np.nan)
print(df[var].value_counts())
print(sum(df[var].isnull()))
# Out:
# [9 0 1]
# 1    19154
# 0     3801
# 9       31
# Name: Released, dtype: int64
# 0
# 1.0    19154
# 0.0     3801
# Name: Released, dtype: int64
# 31

# %%
# Cleaning the ImposedSentenceAllChargeInContactEvent variable

var = 'ImposedSentenceAllChargeInContactEvent'
var2 = 'SentenceTypeAllChargesAtConvictionInContactEvent'
print(df[var2].value_counts())
print(sum(df[var].isnull()))
df.loc[1:10,('ImposedSentenceAllChargeInContactEvent','SentenceTypeAllChargesAtConvictionInContactEvent')]
# Out:
# 4    8779
# 0    8720
# 1    4299
# 2     914
# 9     274
# Name: SentenceTypeAllChargesAtConvictionInContactEvent, dtype: int64
# 0
#    ImposedSentenceAllChargeInContactEvent  \
# 1                                      60
# 2                                      12
# 3                        .985626283367556
# 4
# 5                                      12
# 6                                      36
# 7                                       6
# 8                                      24
# 9                                      12
# 10                       5.91375770020534
#
#     SentenceTypeAllChargesAtConvictionInContactEvent
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  4
# 5                                                  0
# 6                                                  1
# ...

# %%
df = df.rename(columns = {'ImposedSentenceAllChargeInContactEvent':'Sentence_Length','SentenceTypeAllChargesAtConvictionInContactEvent':'Sentence_Type'}) # simplifying the names for purposes of this task
var = 'Sentence_Length'
var2 = 'Sentence_Type'

 # replacing missing sentence_length values with 0 where type = 4:
df.loc[df[var2] == 4, var] = 0

# replacing remaining missing values with nans (where type = 9):
df[var] = df[var].replace(' ',np.nan)
print(sum(df[var].isnull()))

df.loc[1:20,(var,var2)]
# Out:
# 274
#      Sentence_Length  Sentence_Type
# 1                 60              0
# 2                 12              1
# 3   .985626283367556              1
# 4                  0              4
# 5                 12              0
# 6                 36              1
# 7                  6              0
# 8                 24              1
# 9                 12              1
# 10  5.91375770020534              0
# 11                 0              4
# 12                 0              4
# 13               120              1
# 14                24              1
# 15                 0              4
# 16                 0              4
# 17                12              0
# 18                 0              4
# 19                12              0
# 20                12              0

# %% [markdown]
# **Q3.** This question provides some practice doing exploratory data analysis and visualization.
#
# The "relevant" variables for this question are:
#   - `level` - Level of institution (4-year, 2-year)
#   - `aid_value` - The average amount of student aid going to undergraduate recipients
#   - `control` - Public, Private not-for-profit, Private for-profit
#   - `grad_100_value` - percentage of first-time, full-time, degree-seeking undergraduates who complete a degree or certificate program within 100 percent of expected time (bachelor's-seeking group at 4-year institutions)
#
# 1. Load the `./data/college_completion.csv` data with Pandas.
# 2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
# 3. Cross tabulate `control` and `level`. Describe the patterns you see.
# 4. For `grad_100_value`, create a histogram, kernel density plot, boxplot, and statistical description.
# 5. For `grad_100_value`, create a grouped kernel density plot by `control` and by `level`. Describe what you see. Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `grad_100_value` by `level` and `control`. Which institutions appear to have the best graduation rates?
# 6. Create a new variable, `df['levelXcontrol']=df['level']+', '+df['control']` that interacts level and control. Make a grouped kernel density plot. Which institutions appear to have the best graduation rates?
# 7. Make a kernel density plot of `aid_value`. Notice that your graph is "bi-modal", having two little peaks that represent locally most common values. Now group your graph by `level` and `control`. What explains the bi-modal nature of the graph? Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `aid_value` by `level` and `control`.
# 8. Make a scatterplot of `grad_100_value` by `aid_value`. Describe what you see. Now make the same plot, grouping by `level` and then `control`. Describe what you see. For which kinds of institutions does aid seem to increase graduation rates?

# %% [markdown]
# **Q4.** This question uses the Airbnb data to practice making visualizations.
#
#   1. Load the `./data/airbnb_hw.csv` data with Pandas. You should have cleaned the `Price` variable in question 2, and you'll need it later for this question.
#   2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
#   3. Cross tabulate `Room Type` and `Property Type`. What patterns do you see in what kinds of rentals are available? For which kinds of properties are private rooms more common than renting the entire property?
#   4. For `Price`, make a histogram, kernel density, box plot, and a statistical description of the variable. Are the data badly scaled? Are there many outliers? Use `log` to transform price into a new variable, `price_log`, and take these steps again.
#   5. Make a scatterplot of `price_log` and `Beds`. Describe what you see. Use `.groupby()` to compute a desciption of `Price` conditional on/grouped by the number of beds. Describe any patterns you see in the average price and standard deviation in prices.
#   6. Make a scatterplot of `price_log` and `Beds`, but color the graph by `Room Type` and `Property Type`. What patterns do you see? Compute a description of `Price` conditional on `Room Type` and `Property Type`. Which Room Type and Property Type have the highest prices on average? Which have the highest standard deviation? Does the mean or median appear to be a more reliable estimate of central tendency, and explain why?
#   7. We've looked a bit at this `price_log` and `Beds` scatterplot. Use seaborn to make a `jointplot` with `kind=hex`. Where are the data actually distributed? How does it affect the way you think about the plots in 5 and 6?

# %% [markdown]
# **Q5.** Many important datasets contain a race variable, typically limited to a handful of values often including Black, White, Asian, Latino, and Indigenous. This question looks at data gathering efforts on this variable by the U.S. Federal government.
#
# 1. How did the most recent US Census gather data on race?
# 2. Why do we gather these data? What role do these kinds of data play in politics and society? Why does data quality matter?
# 3. Please provide a constructive criticism of how the Census was conducted: What was done well? What do you think was missing? How should future large scale surveys be adjusted to best reflect the diversity of the population? Could some of the Census' good practices be adopted more widely to gather richer and more useful data?
# 4. How did the Census gather data on sex and gender? Please provide a similar constructive criticism of their practices.
# 5. When it comes to cleaning data, what concerns do you have about protected characteristics like sex, gender, sexual identity, or race? What challenges can you imagine arising when there are missing values? What good or bad practices might people adopt, and why?
# 6. Suppose someone invented an algorithm to impute values for protected characteristics like race, gender, sex, or sexuality. What kinds of concerns would you have?

# %% [markdown]
# 1. The 2020 Census included two separate questions: one for race and one for Hispanic or Latino origin. This separation has been required since 1997 when the US Office of Management and Budget revised their standards. Race is of course self reported on the survey, and respondents can select multiple options. As per the standards set by the OMB, the survey has five minimum categories for race (American Indian or Alaka Native, Asian, Black or African American, Native Hawaiin or Other Pacific Islander, and White), and in accorcance with legislation passed by Congress, the survey also includes a sixth option ("Some Other Race"). The 2020 Census also included new write-in areas so that respondents from all backgrounds could detail their racial identities. In addition to data that comes directly from respondents, the US Census incorporates data from other sources, such as state and local governments as well as commercial entities (Census.gov).
# 2. These data are collected for a number of reasons. Many federal programs rely on access to accurate demographic information for sufficient funding and optimal functioning; for example, the Financial Assistance and Social Services (FASS) program gives financial aid to tribal members who cannot obtain welfare. A program like this needs to have an accurate estimate of how many people they will be serving. Data on race and ethncity is also used in the enforcement of antidiscrimination policies as well as many other federal efforts. These data ultimately play a major role in policy, and thus also play a major role in society and politics. Poor data quality and inaccurate estimates (among other factors, of course) can result in governmental failure to serve the needs of racial groups equitably. Additionally, the Census is used to determine how many seats each state has in the House of Representatives, and the House of Representatives obviously plays an enormous role in American politics and society.
# 3. I think that including additional write-in sections is helpful in theory but may not yield the anticipated results. Respondents may not be motivated to detail their racial backgrounds. I think that it might be a better idea to offer more answer choices than to expect respondents to write in the specifics of their racial backgrounds. I do think that including these write-in areas is objectively a good idea; I just think that there may be better options for capturing diversity more accurately. I think future large scale surveys should present additional answer choices to questions about race and should be available in many forms; allowing respondents to submit their responses digitally was a step in the right direction, in my opinion, and I think that the more ways by which we can submit census data the better. I think that, in general, the Census employs some solid practices in their efforts to obtain accurate and representative data. These practices could definitely be applied more widely, although there are cost concerns. Census data collection is effortful and costly.
# 4. The 2020 Census asked respondents to identify their current sex (male or female) but did not include any questions regarding gender identity or sexual orientation. However, I believe the Census Bureau is now devoting resources to determining how to best ask about/capture gender and sexual orientation, so hopefully the 2030 Census will reflect these new efforts. I think that while asking for the respondent's sex is useful in a lot of ways, it is also rather reductive to not ask about gender identity or sexual orientation. I think these additional categories could provide valuable information that could ultimately help many individuals throughout the country. Gender and sexual orientation are used as grounds for discrimination, and that alone should be reason enough to include them in the Census.
# 5. With protected characteristics, I think missing values may be particularly difficult to explain, as there is a wide range of possible reasons why people may choose not to respond. It can be difficult and even impossible to determine why someone may have left these questions unanswered, and patterns of nonresponse may lead to skewed estimates. To remedy the problems associated with missing values in these areas, people may attempt to impute values, which could be helpful or harmful. People may also make assumptions about why values are missing, which again could be helpful if their assumptions are correct or harmful if their assumptions are incorrect. It can be tempting to make assumptions and/or impute values, but it is important to recognize that these practices are risky and could potentially lead to inaccurate estimates and conclusions.
# 6. I think that an algorithm for imputing values for protected characteristics may run into an issue that is similar to the problem discussed in class with the WWII planes; it may miss an entire subset of responses based on the assumption that these values are missing because they are simply not occurring among the population. This assumption may or may not be true in a given dataset, but it is a risky conclusion to draw regardless. I also think that having limited options to choose for questions about sexuality/gender/race may lead some people to not respond, so missing values may sometimes be a result of people not seeing their identities represented in the answer choice options, and I think an algorithm would have a hard time accurately imputing values for these individuals.

# %% [markdown]
# **Q6.** Open the `./data/CBO_data.pdf` file. This contains tax data for 2019, explaining where the money comes from that the U.S. Federal Government Spends in terms of taxation on individuals/families and payroll taxes (the amount that your employer pays in taxes on your wages).
#
# For some context, the Federal government ultimately spent about $4.4 trillion in 2019, which was 21% of GDP (the total monetary value of all goods and services produced within the United States). Individual Income Taxes is the amount individuals pay on their wages to the Federal government, Corporate Income Taxes is the taxes individuals pay on capital gains from investment when they sell stock or other financial instruments, Payroll Taxes is the tax your employer pays on your wages, Excises and Customs Duties are taxes on goods or services like sin taxes on cigarettes or alcohol, and Estate and Gift Taxes are taxes paid on transfers of wealth to other people.
#
# 1. Get the Millions of Families and Billions of Dollars data into a .csv file and load it with Pandas.
# 2. Create a bar plot of individual income taxes by income decile. Explain what the graph shows. Why are some values negative?
# 3. Create a bar plot of Total Federal Taxes by income decile. Which deciles are paying net positive amounts, and which are paying net negative amounts?
# 4. Create a stacked bar plot for which Total Federal Taxes is grouped by Individual Income Taxes, Payroll Taxes, Excises and Customs Duties, and Estate and Gift Taxes. How does the share of taxes paid vary across the adjusted income deciles? (Hint: Are these the kind of data you want to melt?)
# 5. Below the Total line for Millions of Families and Billions of Dollars, there are data for the richest of the richest families. Plot this alongside the bars for the deciles above the Total line. Describe your results.
# 6. Get the Percent Distribution data into a .csv file and load it with Pandas. Create a bar graph of Total Federal Taxes by income decile.
# 7. A tax system is progressive if higher-income and wealthier individuals pay more than lower-income and less wealthy individuals, and it is regressive if the opposite is true. Is the U.S. tax system progressive in terms of amount paid? In terms of the percentage of the overall total?
# 8. Do the rich pay enough in taxes? Defend your answer.
